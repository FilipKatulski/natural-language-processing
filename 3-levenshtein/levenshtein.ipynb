# %% [markdown]
# # Levenshtein distance and spelling corrections
#
# This notebook is a continuation of a Google Colab notebook 'nlp3.ipynb'.
#
# The version of macOS used to solve this task does not support Morfeusz2 Python Bindings.

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import parallel_bulk
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# Please, for this Notebook to run disable security features (SSL) in elasticsearch.yml.

# %%
es = Elasticsearch("http://localhost:9200/")
if es.ping():
    print('Yay Connected!')
    print(es.info().body)
else:
    print('Awww it could not connect!')
    print(es.ping())
# Out:
# Yay Connected!
# {'name': 'MacBook-Pro-5.lan', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'rJQK1DceS2-i7H25KMdmOA', 'version': {'number': '8.5.1', 'build_flavor': 'default', 'build_type': 'tar', 'build_hash': 'c1310c45fc534583afe2c1c03046491efba2bba2', 'build_date': '2022-11-09T21:02:20.169855900Z', 'build_snapshot': False, 'lucene_version': '9.4.1', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %% [markdown]
# Unpack df_corrections pickle:

# %%
df_corrections = pd.read_pickle("df_corrections.pkl")

# %% [markdown]
# 12. Load SGJP dictionary (Słownik SGJP dane tekstowe) to ElasticSearch (one document for each form) and use fuzzy matching to obtain the possible corrections of the 30 words with 5 occurrences that do not belong to the dictionary.

# %%
es_index = "polish_bills_recommendation"

if es.indices.exists(index=es_index):
    es.indices.delete(index=es_index)

res = es.indices.create(
    index=es_index,
    mappings={
        'properties': {
            'text': {
                'type': "text",
                'analyzer': "keyword"
            }
        }
    }
)
res
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'polish_bills_recommendation'})

# %%
with open("sgjp-20221113.tab", 'r') as f:
    sgjp = f.read().split('\n')[28:-1]

# %%
def map_words_for_bulk_upload(lines):
    for i, line in enumerate(lines):
        word, *_ = line.split('\t')
        yield {
            '_op_type': 'create',
            '_index': es_index,
            '_id': i,
            'text': word
        }

def get_corrections(word):
    res = es.search(index=es_index,
                    query={'match': {'text': {'query': word, 'fuzziness': 2}}},
                    filter_path=["hits.hits._source.text"])
    return ", ".join(hit['_source']['text'] for hit in res['hits']['hits'])

# %%
progress_bar = tqdm(desc="Uploading SGJP to ES", total=len(sgjp))
for _ in parallel_bulk(client=es, actions=map_words_for_bulk_upload(sgjp)):
    progress_bar.update(1)
# Out:
# Uploading SGJP to ES: 100%|█████████▉| 7409501/7412267 [06:19<00:00, 19601.46it/s]

# %%
df_corrections['correction_es'] = df_corrections['token'].apply(get_corrections)
df_corrections
# Out:
#             token  count  rank   correction  \
# 371          późn   1065   372         plan
# 1435          gmo    298  1436           go
# 1975          sww    216  1976          swe
# 2174          skw    196  2175           kw
# 2501           ex    167  2502           ix
# 2571          ike    162  2572          ile
# 3350   remediacji    120  3351     mediacji
# 3733          ure    103  3734           ue
# 3907          uke     97  3908           ue
# 3993           kn     95  3994           on
# 4464           cn     83  4465           co
# 4531        pkwiu     81  4532        kwitu
# 4674          udt     77  4675          ust
# 5053        bswsg     70  5054        bswsg
# 5285         bswp     66  5286          bhp
# 5455  biobójczych     63  5456  biobójczych
# 6124          phs     53  6125          prs
# 7012         hcfc     44  7013          cfc
# 7230          fep     42  7231           fe
# 7335          mgo     41  7336           go
# 7391          utk     40  7392          ust
# 8002          frd     36  8003          art
# 8057        uokik     35  8058         koki
# 8080          ron     35  8081          rok
# 8302         doke     34  8303         doki
# 8307         cbśp     34  8308          nbp
# 8505        vitro     32  8506        nitro
# 8571          pcn     32  8572          pan
# 8618        haccp     32  8619        haccp
# 8791          its     31  8792          itp
#
#                                           correction_es
# 371   późni, późno, późna, późna, późne, późne, późn...
# 1435   dmo, emo, emo, emo, emo, emo, emo, emo, emo, emo
# 1975   swa, siw, sów, suw, swe, swe, swe, swe, swą, swą
# 2174  sakw, siw, ska, ski, sków, sów, suw, kw, Bokw,...
# 2501            Rex, em, eś, ee, ef, ef, eh, ej, el, em
# 2571  Mike, Mike, Mike, Mike, Nike, ikr, iks, iks, i...
# 3350  repudiacji, repudiacji, repudiacji, remediach,...
# 3733  Bure, Bure, Sure, bure, bure, bure, bure, uje,...
# 3907  uje, ule, Bek, Bek, Age, Ale, Ale, Ale, Ale, Buje
# 3993            en, in, ka, kan, kb, ka, ki, ki, ki, ką
# 4464            ce, cen, ci, ck, ck, ck, ck, ck, ck, ck
# 4531  pawiu, pawiu, pawiu, pawiu, Akwilu, Akwil, Akw...
# 4674   udu, udy, uda, uda, uda, udo, udu, ust, Jdt, ust
# 5053                                              bywsi
# 5285  Isep, Osip, Osip, Osip, bawi, biwa, biwo, biwy...
# 5455
# 6124    phi, phi, phy, pąs, pas, pas, pas, pas, phu, ps
# 7012  Ocic, chcic, chcąc, hafn, hafy, harc, herc, hu...
# 7230   Cep, Dep, Hep, Lep, Lep, Lep, Wep, Zep, cep, cep
# 7335  Ago, Igo, ago, ago, ego, mgr, mgło, mgło, mgło...
# 7391  tuk, utka, utok, tuk, utyk, ut, Ata, Ata, Atek...
# 8002  Ord, frr, fru, Urd, ford, ord, Art, Art, Bard,...
# 8057  Bobik, Bobik, Bokiń, Bokin, Bolik, Bolik, Boni...
# 8080  Aron, Bron, Bron, Bon, Bon, Bon, Con, Con, Don...
# 8302  doje, doki, doku, doku, doku, doker, dole, doż...
# 8307  chap, chap, chip, chip, ciap, ciap, ciap, ciep...
# 8505  Pitro, Pitro, litro, mitro, nitro, Bibro, Bibr...
# 8571      pan, pin, pun, dcn, płn, pn, pn, pn, Ben, Ben
# 8618  hacce, Cacce, Dacce, Dacce, Dacce, Gacce, Gacc...
# 8791    iks, iks, iks, itr, itd, itp, ts, Ata, Ata, Ast
# Uploading SGJP to ES: 100%|██████████| 7412267/7412267 [06:31<00:00, 19601.46it/s]
